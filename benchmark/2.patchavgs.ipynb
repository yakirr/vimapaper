# %%
import os
import numpy as np
import pandas as pd
import scanpy as sc

# %%
def run_patchavgs(dsetname):
    for embedding in ['avgmm', 'celltypeabundance']:
        d = sc.read_h5ad(f'_data/{dsetname}/patches_{embedding}.h5ad')
        print(d.shape)
        d.write(f'_embeddings/{dsetname}_patch{embedding}_noharm.h5ad')

# %%
run_patchavgs('ALZ')
# Out:
# (70898, 10)
# (70898, 24)
